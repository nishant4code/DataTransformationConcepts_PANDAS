# %%
import pandas as pd

# %%
people = {'first':['nishant', 'akshay', 'manoj'],
         'last':['chauhan', 'kumar', 'chauhan'],
         'email':['nich@gmail.com', 'akku@gmail.com', 'mach@gmail.com']}
df = pd.DataFrame(people)
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshay    kumar  akku@gmail.com
# 2    manoj  chauhan  mach@gmail.com

# %%
#renaming columns
#method-1
df.columns = ['first_name', 'last_name', 'email_id']
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshay     kumar  akku@gmail.com
# 2      manoj   chauhan  mach@gmail.com

# %%
#renaming columns
#method-2
df.rename(columns = {'first_name':'first',
                    'last_name':'last',
                    'email_id':'email'}, inplace=True)
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshay    kumar  akku@gmail.com
# 2    manoj  chauhan  mach@gmail.com

# %%
#renaming method
#method-3
df.columns = [x.upper() for x in df.columns]
df
# Out:
#      FIRST     LAST           EMAIL
# 0  nishant  chauhan  nich@gmail.com
# 1   akshay    kumar  akku@gmail.com
# 2    manoj  chauhan  mach@gmail.com

# %%
df
# Out:
#      FIRST     LAST           EMAIL
# 0  nishant  chauhan  nich@gmail.com
# 1   akshay    kumar  akku@gmail.com
# 2    manoj  chauhan  mach@gmail.com

# %%
df.columns = ['first_name', 'last_name', 'email_id']
df
# Out:
# Index(['first@name', 'last@name', 'email@id'], dtype='object')

# %%
df
# Out:
# Index(['first@name', 'last@name', 'email@id'], dtype='object')

# %%
#updating columns
df.columns = df.columns.str.replace('@', '#')

# %%
df.columns
# Out:
# Index(['first#name', 'last#name', 'email#id'], dtype='object')

# %%
df.columns = df.columns.str.replace('#', '_')

# %%
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshay     kumar  akku@gmail.com
# 2      manoj   chauhan  mach@gmail.com

# %%
#updating complete row using loc[] method
df.loc[2] = ['manish', 'sherawat', 'mash@gmail.com']

# %%
#updating particular row value using loc[] method
df.loc[2, ['last_name', 'email_id']] = ['singh', 'masi@gmail.com']

# %%
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshay     kumar  akku@gmail.com
# 2     manish     singh  masi@gmail.com

# %%
#updating single row value
df.loc[2, 'last_name'] = 'chauhan'

# %%
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshay     kumar  akku@gmail.com
# 2     manish   chauhan  masi@gmail.com

# %%
#updating single row value
df.at[2, 'email_id'] = 'mach@gmail.com' # .at also works same as .loc

# %%
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshay     kumar  akku@gmail.com
# 2     manish   chauhan  mach@gmail.com

# %%
filt = (df['email_id'] == 'akku@gmail.com')
df.loc[filt, 'first_name'] = 'akshit'
df
# Out:
#   first_name last_name        email_id
# 0    nishant   chauhan  nich@gmail.com
# 1     akshit     kumar  akku@gmail.com
# 2     manish   chauhan  mach@gmail.com

# %%
df.rename(columns = {'first_name':'first',
                    'last_name':'last',
                    'email_id':'email'}, inplace=True)

# %%
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshit    kumar  akku@gmail.com
# 2   manish  chauhan  mach@gmail.com

# %%
#updating multiple row values
df['email'].str.upper()
# Out:
# 0    NICH@GMAIL.COM
# 1    AKKU@GMAIL.COM
# 2    MACH@GMAIL.COM
# Name: email, dtype: object

# %%
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshit    kumar  akku@gmail.com
# 2   manish  chauhan  mach@gmail.com

# %%
#apply method on Series
df['email'].apply(len)
# Out:
# 0    14
# 1    14
# 2    14
# Name: email, dtype: int64

# %%
df['email'] = df['email'].apply(lambda x: x.upper())

# %%
df
# Out:
#      first     last           email
# 0  nishant  chauhan  NICH@GMAIL.COM
# 1   akshit    kumar  AKKU@GMAIL.COM
# 2   manish  chauhan  MACH@GMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshit    kumar  akku@gmail.com
# 2   manish  chauhan  mach@gmail.com

# %%
#applymap method on DataFrame
df.applymap(len)
# Out:
#    first  last  email
# 0      7     7     14
# 1      6     5     14
# 2      6     7     14

# %%
#min method
df.apply(lambda x: x.min()) #min(), max() are more useful in numeric data not string data
# Out:
# first            akshit
# last            chauhan
# email    akku@gmail.com
# dtype: object

# %%
# applymap() works on DataFrame
df.applymap(str.upper)
# Out:
#      first     last           email
# 0  NISHANT  CHAUHAN  NICH@GMAIL.COM
# 1   AKSHIT    KUMAR  AKKU@GMAIL.COM
# 2   MANISH  CHAUHAN  MACH@GMAIL.COM

# %%
#map() method works on Series
df['first'].map({'nishant':'nikhil', 'manish':'manjit'}) # values which are not in map() will convert to NaN
#so instead of .map(), we should use .replace()
# Out:
# 0    nikhil
# 1       NaN
# 2    manjit
# Name: first, dtype: object

# %%
df['first'].replace({'nishant':'nikhil', 'manish':'manjit'}) #rest values will remain same as it is
# Out:
# 0    nikhil
# 1    akshit
# 2    manjit
# Name: first, dtype: object

# %%
df
# Out:
#      first     last           email
# 0  nishant  chauhan  nich@gmail.com
# 1   akshit    kumar  akku@gmail.com
# 2   manish  chauhan  mach@gmail.com

# %%
df1 = pd.read_csv('D:\Data\stack_overflow_csv\survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('D:\Data\stack_overflow_csv\survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df1.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df1.rename(columns = {'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
df1.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
#filling null values with 0
filt = df1['SalaryUSD'].isnull()
filt
df1.loc[filt, 'SalaryUSD'] = 0

# %%
df1.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df1['Hobbyist'] = df1['Hobbyist'].map({'Yes':True, 'No':False})

# %%
df1.head(2)
# Out:
#                                         MainBranch  Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      True
# 2           I am a student who is learning to code     False
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...
